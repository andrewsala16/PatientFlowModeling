# %%
import pandas as pd
import matplotlib.pyplot as plt

var = pd.read_excel('/content/drive/MyDrive/Book.xlsx')

x4 = list(var['X values for 4'])
y4 = list(var['Y values for 4'])

x5 = list(var['X values for 5'])
y5 = list(var['Y values for 5'])

x6 = list(var['X values for 6'])
y6 = list(var['Y values for 6'])

x7 = list(var['X values for 7'])
y7 = list(var['Y values for 7'])

x8 = list(var['X values for 8'])
y8 = list(var['Y values for 8'])


plt.plot(x4, y4, label = '4')
plt.plot(x5, y5, label = '5')
plt.plot(x6, y6, label = '6')
plt.plot(x7, y7, label = '7')
plt.plot(x8, y8, label = '8')


plt.ylabel('Avg. Waiting Time (min)')
plt.xlabel('Number of Physicians')
plt.legend(title = "Avg. Arrival Time")
plt.show()
